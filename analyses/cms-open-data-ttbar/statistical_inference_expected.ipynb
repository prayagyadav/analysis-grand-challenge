# %% [markdown]
# # Statistical Inference with Combine - expected results
#
# When working on a real analysis, you do not start immediately running fits using the observed data. By doing so, you could indeed bias the design of your analysis.
# For this reason, it is important to produce the so-called "expected" results, obtained either by running fits on toys generated from the physics model or by using an Asimov dataset, in which statistical fluctuations are suppressed.
#
# In Combine, performing fits on toys is possible by adding the flag `-t #toys#`, while to run on an Asimov dataset we need to add `-t -1`.
# In what follows, we will perform fits on an Asimov dataset, injecting a signal strenght of $\mu=1$ via the flag `--expectSignal 1`.

# %%
from IPython.display import display, IFrame
import os

# %%
# %env PATH=opt/conda/bin/:/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tmp/HiggsAnalysis/CombinedLimit/build/bin
# %env LD_LIBRARY_PATH=/opt/conda/lib/:/tmp/HiggsAnalysis/CombinedLimit/build/lib
# %env PYTHONPATH=/tmp/HiggsAnalysis/CombinedLimit/build/lib/python
# Out:
# env: PATH=opt/conda/bin/:/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tmp/HiggsAnalysis/CombinedLimit/build/bin
# env: LD_LIBRARY_PATH=/opt/conda/lib/:/tmp/HiggsAnalysis/CombinedLimit/build/lib
# env: PYTHONPATH=/tmp/HiggsAnalysis/CombinedLimit/build/lib/python

# %% [markdown]
# ## Impacts

# %%
# needed because of https://github.com/cms-analysis/HiggsAnalysis-CombinedLimit/issues/1049
os.environ["CMSSW_BASE"] = "."
os.environ["SCRAM_ARCH"] = "."

# %%
# !combineTool.py -M Impacts -d datacard_by_hand.root --robustFit 1 --doInitialFit -m 125 -t -1 --expectSignal 1 -n expected
# Out:
# Have POIs: ['r']
# >> combine -M MultiDimFit -n _initialFit_expected --algo singles --redefineSignalPOIs r --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# best fit parameter values and profile-likelihood uncertainties:
#    r :    +1.000   -0.092/+0.111 (68%)
# Done in 0.00 min (cpu), 0.00 min (real)

# %%
# !combineTool.py -M Impacts -d datacard_by_hand.root --robustFit 1 --doFits -m 125 -t -1 --expectSignal 1 -n expected
# Out:
# Have POIs: ['r']
# Have parameters: 33
# >> combine -M MultiDimFit -n _paramFit_expected_ME_var --algo impact --redefineSignalPOIs r -P ME_var --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter :   Best-fit               r
#   ME_var    :   +0.000  -0.213/+0.224  -0.025/+0.030
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_PS_var --algo impact --redefineSignalPOIs r -P PS_var --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter :   Best-fit               r
#   PS_var    :   +0.000  -0.316/+0.290  +0.072/-0.062
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_btag_var_0 --algo impact --redefineSignalPOIs r -P btag_var_0 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter  :   Best-fit               r
#   btag_var_0 :   +0.000  -0.522/+0.688  -0.004/-0.009
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_btag_var_1 --algo impact --redefineSignalPOIs r -P btag_var_1 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter  :   Best-fit               r
#   btag_var_1 :   +0.000  -0.817/+0.878  +0.016/-0.024
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_btag_var_2 --algo impact --redefineSignalPOIs r -P btag_var_2 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter  :   Best-fit               r
#   btag_var_2 :   +0.000  -0.939/+0.954  +0.033/-0.032
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_btag_var_3 --algo impact --redefineSignalPOIs r -P btag_var_3 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter  :   Best-fit               r
#   btag_var_3 :   +0.000  -0.965/+0.970  +0.037/-0.033
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_lumi --algo impact --redefineSignalPOIs r -P lumi --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter :   Best-fit               r
#   lumi      :   +0.000  -0.977/+0.975  +0.028/-0.025
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_prop_binbin4j1b_bin0 --algo impact --redefineSignalPOIs r -P prop_binbin4j1b_bin0 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binbin4j1b_bin0 :   +0.000  -0.615/+0.631  -0.010/+0.015
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_prop_binbin4j1b_bin1 --algo impact --redefineSignalPOIs r -P prop_binbin4j1b_bin1 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binbin4j1b_bin1 :   -0.000  -0.597/+0.610  -0.008/+0.022
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_prop_binbin4j1b_bin10 --algo impact --redefineSignalPOIs r -P prop_binbin4j1b_bin10 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binbin4j1b_bin10 :   -0.000  -0.626/+0.639  -0.028/+0.032
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_prop_binbin4j1b_bin2 --algo impact --redefineSignalPOIs r -P prop_binbin4j1b_bin2 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binbin4j1b_bin2 :   -0.000  -0.704/+0.697  +0.020/-0.003
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_prop_binbin4j1b_bin3 --algo impact --redefineSignalPOIs r -P prop_binbin4j1b_bin3 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binbin4j1b_bin3 :   -0.000  -0.730/+0.740  -0.010/+0.006
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_prop_binbin4j1b_bin4 --algo impact --redefineSignalPOIs r -P prop_binbin4j1b_bin4 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binbin4j1b_bin4 :   -0.000  -0.647/+0.635  +0.028/-0.010
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_prop_binbin4j1b_bin5 --algo impact --redefineSignalPOIs r -P prop_binbin4j1b_bin5 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binbin4j1b_bin5 :   -0.000  -0.621/+0.620  +0.015/-0.005
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_prop_binbin4j1b_bin6 --algo impact --redefineSignalPOIs r -P prop_binbin4j1b_bin6 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binbin4j1b_bin6 :   -0.000  -0.634/+0.652  +0.017/-0.018
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_prop_binbin4j1b_bin7 --algo impact --redefineSignalPOIs r -P prop_binbin4j1b_bin7 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binbin4j1b_bin7 :   -0.000  -0.586/+0.598  -0.002/+0.004
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_prop_binbin4j1b_bin8 --algo impact --redefineSignalPOIs r -P prop_binbin4j1b_bin8 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binbin4j1b_bin8 :   -0.000  -0.653/+0.663  -0.047/+0.047
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_prop_binbin4j1b_bin9 --algo impact --redefineSignalPOIs r -P prop_binbin4j1b_bin9 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binbin4j1b_bin9 :   -0.000  -0.597/+0.613  -0.023/+0.032
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_prop_binbin4j2b_bin0 --algo impact --redefineSignalPOIs r -P prop_binbin4j2b_bin0 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binbin4j2b_bin0 :   -0.000  -0.940/+0.946  +0.010/-0.004
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_prop_binbin4j2b_bin1 --algo impact --redefineSignalPOIs r -P prop_binbin4j2b_bin1 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binbin4j2b_bin1 :   -0.000  -0.982/+0.984  -0.002/+0.003
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_prop_binbin4j2b_bin10 --algo impact --redefineSignalPOIs r -P prop_binbin4j2b_bin10 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter             :   Best-fit               r
#   prop_binbin4j2b_bin10 :   -0.000  -0.820/+0.823  -0.007/+0.007
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_prop_binbin4j2b_bin2 --algo impact --redefineSignalPOIs r -P prop_binbin4j2b_bin2 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binbin4j2b_bin2 :   -0.000  -0.933/+0.934  -0.005/+0.008
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_prop_binbin4j2b_bin3 --algo impact --redefineSignalPOIs r -P prop_binbin4j2b_bin3 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binbin4j2b_bin3 :   -0.000  -0.839/+0.821  +0.037/-0.025
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_prop_binbin4j2b_bin4 --algo impact --redefineSignalPOIs r -P prop_binbin4j2b_bin4 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binbin4j2b_bin4 :   -0.000  -0.773/+0.776  +0.004/+0.004
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_prop_binbin4j2b_bin5 --algo impact --redefineSignalPOIs r -P prop_binbin4j2b_bin5 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binbin4j2b_bin5 :   -0.000  -0.777/+0.775  +0.005/-0.004
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_prop_binbin4j2b_bin6 --algo impact --redefineSignalPOIs r -P prop_binbin4j2b_bin6 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binbin4j2b_bin6 :   -0.000  -0.791/+0.791  +0.004/-0.001
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_prop_binbin4j2b_bin7 --algo impact --redefineSignalPOIs r -P prop_binbin4j2b_bin7 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binbin4j2b_bin7 :   -0.000  -0.783/+0.786  -0.006/+0.005
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_prop_binbin4j2b_bin8 --algo impact --redefineSignalPOIs r -P prop_binbin4j2b_bin8 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binbin4j2b_bin8 :   -0.000  -0.695/+0.706  -0.008/+0.012
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_prop_binbin4j2b_bin9 --algo impact --redefineSignalPOIs r -P prop_binbin4j2b_bin9 --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter            :   Best-fit               r
#   prop_binbin4j2b_bin9 :   -0.000  -0.675/+0.703  +0.000/-0.013
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_pt_res --algo impact --redefineSignalPOIs r -P pt_res --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter :   Best-fit               r
#   pt_res    :   +0.000  -0.687/+0.679  +0.020/-0.016
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_pt_scale --algo impact --redefineSignalPOIs r -P pt_scale --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter :   Best-fit               r
#   pt_scale  :   +0.000  -0.376/+0.342  -0.036/+0.020
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_scale --algo impact --redefineSignalPOIs r -P scale --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter :   Best-fit               r
#   scale     :   +0.000  -0.518/+0.550  +0.066/-0.056
# Done in 0.00 min (cpu), 0.00 min (real)
# >> combine -M MultiDimFit -n _paramFit_expected_scale_var --algo impact --redefineSignalPOIs r -P scale_var --floatOtherPOIs 1 --saveInactivePOI 1 --robustFit 1 -t -1 --expectSignal 1 -m 125 -d datacard_by_hand.root
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# Parameter impacts:
#   Parameter :   Best-fit               r
#   scale_var :   +0.000  -0.984/+0.984  -0.003/+0.004
# Done in 0.00 min (cpu), 0.00 min (real)

# %%
# !combineTool.py -M Impacts -d datacard_by_hand.root --robustFit 1 --output impacts_expected.json -m 125 -t -1 --expectSignal 1 -n expected
# Out:
# Have POIs: ['r']
# Have parameters: 33

# %%
# !plotImpacts.py -i impacts_expected.json -o combine_plots/impacts_expected
# Out:
# >> Doing page 0, have 30 parameters
# Info in <TCanvas::Print>: pdf file ./combine_plots/impacts_expected.pdf has been created using the current canvas
# TCanvas::Constructor:0: RuntimeWarning: Deleting canvas with same name: combine_plots/impacts_expected
# >> Doing page 1, have 3 parameters
# Info in <TCanvas::Print>: Current canvas added to pdf file ./combine_plots/impacts_expected.pdf and file closed

# %%
pdf_path = "combine_plots/impacts_expected.pdf"
display(IFrame(pdf_path, width=800, height=600))
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="combine_plots/impacts_expected.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Pre- and post-fit distributions

# %%
# !combine -M FitDiagnostics datacard_by_hand.root --saveShapes --saveWithUncertainties -n FitDiagnosticsStuffExpected -t -1 --expectSignal 1
# Out:
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is FitDiagnostics
# [WARNING]: Unable to determine uncertainties on all fit parameters in b-only fit. The option --saveWithUncertainties will be ignored as it would lead to incorrect results. Have a look at https://cms-analysis.github.io/HiggsAnalysis-CombinedLimit/part3/nonstandard/#fit-parameter-uncertainties for more information.
# [WARNING]: Unable to determine uncertainties on all fit parameters in s+b fit. The option --saveWithUncertainties will be ignored as it would lead to incorrect results. Have a look at https://cms-analysis.github.io/HiggsAnalysis-CombinedLimit/part3/nonstandard/#fit-parameter-uncertainties for more information.
#
#  --- FitDiagnostics ---
# Best fit r: 1  -0.09308/+0.111506  (68% CL)
# Done in 0.03 min (cpu), 0.03 min (real)

# %%
# !for region in bin4j1b bin4j2b; do for shape in shapes_prefit shapes_fit_b shapes_fit_s; do python3 combine_scripts/postFitPlot_new.py --input_file fitDiagnosticsFitDiagnosticsStuffExpected.root --shape_type $shape --region $region --extra_suffix _expected; done; done
# Out:
# Info in <TCanvas::Print>: png file combine_plots/stacked_plot_shapes_prefit_bin4j1b_expected.png has been created
# Info in <TCanvas::Print>: pdf file combine_plots/stacked_plot_shapes_prefit_bin4j1b_expected.pdf has been created
# Info in <TCanvas::Print>: png file combine_plots/stacked_plot_shapes_fit_b_bin4j1b_expected.png has been created
# Info in <TCanvas::Print>: pdf file combine_plots/stacked_plot_shapes_fit_b_bin4j1b_expected.pdf has been created
# Info in <TCanvas::Print>: png file combine_plots/stacked_plot_shapes_fit_s_bin4j1b_expected.png has been created
# Info in <TCanvas::Print>: pdf file combine_plots/stacked_plot_shapes_fit_s_bin4j1b_expected.pdf has been created
# Info in <TCanvas::Print>: png file combine_plots/stacked_plot_shapes_prefit_bin4j2b_expected.png has been created
# Info in <TCanvas::Print>: pdf file combine_plots/stacked_plot_shapes_prefit_bin4j2b_expected.pdf has been created
# Info in <TCanvas::Print>: png file combine_plots/stacked_plot_shapes_fit_b_bin4j2b_expected.png has been created
# Info in <TCanvas::Print>: pdf file combine_plots/stacked_plot_shapes_fit_b_bin4j2b_expected.pdf has been created
# Info in <TCanvas::Print>: png file combine_plots/stacked_plot_shapes_fit_s_bin4j2b_expected.png has been created
# Info in <TCanvas::Print>: pdf file combine_plots/stacked_plot_shapes_fit_s_bin4j2b_expected.pdf has been created

# %%
display(IFrame("combine_plots/stacked_plot_shapes_prefit_bin4j1b_expected.png", width=800, height=600))
display(IFrame("combine_plots/stacked_plot_shapes_fit_s_bin4j1b_expected.png", width=800, height=600))
display(IFrame("combine_plots/stacked_plot_shapes_prefit_bin4j2b_expected.png", width=800, height=600))
display(IFrame("combine_plots/stacked_plot_shapes_fit_s_bin4j2b_expected.png", width=800, height=600))
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="combine_plots/stacked_plot_shapes_prefit_bin4j1b_expected.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#         <iframe
#             width="800"
#             height="600"
#             src="combine_plots/stacked_plot_shapes_fit_s_bin4j1b_expected.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#         <iframe
#             width="800"
#             height="600"
#             src="combine_plots/stacked_plot_shapes_prefit_bin4j2b_expected.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
#         <iframe
#             width="800"
#             height="600"
#             src="combine_plots/stacked_plot_shapes_fit_s_bin4j2b_expected.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Likelihood scan for $\mu$

# %%
# !combine -M MultiDimFit datacard_by_hand.root -n .datacard_by_hand.snapshot.expected --rMin -1 --rMax 4 --saveWorkspace -t -1 --expectSignal 1
# Out:
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#
#  --- MultiDimFit ---
# best fit parameter values:
#    r :    +1.000
# Done in 0.00 min (cpu), 0.00 min (real)

# %%
# !combine -M MultiDimFit higgsCombine.datacard_by_hand.snapshot.expected.MultiDimFit.mH120.root -n .datacard_by_hand_expected --rMin 0 --rMax 2 --algo grid --points 80 --snapshotName MultiDimFit -t -1 --expectSignal 1
# Out:
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#  POI: r= 1 -> [0,2]
# Point 0/80 r = 0.0125
# Point 1/80 r = 0.0375
# Point 2/80 r = 0.0625
# Point 3/80 r = 0.0875
# Point 4/80 r = 0.1125
# Point 5/80 r = 0.1375
# Point 6/80 r = 0.1625
# Point 7/80 r = 0.1875
# Point 8/80 r = 0.2125
# Point 9/80 r = 0.2375
# Point 10/80 r = 0.2625
# Point 11/80 r = 0.2875
# Point 12/80 r = 0.3125
# Point 13/80 r = 0.3375
# Point 14/80 r = 0.3625
# Point 15/80 r = 0.3875
# Point 16/80 r = 0.4125
# Point 17/80 r = 0.4375
# Point 18/80 r = 0.4625
# Point 19/80 r = 0.4875
# Point 20/80 r = 0.5125
# Point 21/80 r = 0.5375
# Point 22/80 r = 0.5625
# Point 23/80 r = 0.5875
# Point 24/80 r = 0.6125
# [WARNING] Minimization finished with status 1 (covariance matrix forced positive definite), this could indicate a problem with the minimum!
# Point 25/80 r = 0.6375
# Point 26/80 r = 0.6625
# Point 27/80 r = 0.6875
# Point 28/80 r = 0.7125
# Point 29/80 r = 0.7375
# Point 30/80 r = 0.7625
# Point 31/80 r = 0.7875
# Point 32/80 r = 0.8125
# Point 33/80 r = 0.8375
# Point 34/80 r = 0.8625
# Point 35/80 r = 0.8875
# Point 36/80 r = 0.9125
# Point 37/80 r = 0.9375
# Point 38/80 r = 0.9625
# Point 39/80 r = 0.9875
# Point 40/80 r = 1.0125
# Point 41/80 r = 1.0375
# Point 42/80 r = 1.0625
# Point 43/80 r = 1.0875
# Point 44/80 r = 1.1125
# Point 45/80 r = 1.1375
# Point 46/80 r = 1.1625
# Point 47/80 r = 1.1875
# Point 48/80 r = 1.2125
# Point 49/80 r = 1.2375
# Point 50/80 r = 1.2625
# Point 51/80 r = 1.2875
# Point 52/80 r = 1.3125
# Point 53/80 r = 1.3375
# Point 54/80 r = 1.3625
# Point 55/80 r = 1.3875
# Point 56/80 r = 1.4125
# Point 57/80 r = 1.4375
# Point 58/80 r = 1.4625
# Point 59/80 r = 1.4875
# Point 60/80 r = 1.5125
# Point 61/80 r = 1.5375
# Point 62/80 r = 1.5625
# Point 63/80 r = 1.5875
# Point 64/80 r = 1.6125
# Point 65/80 r = 1.6375
# Point 66/80 r = 1.6625
# Point 67/80 r = 1.6875
# Point 68/80 r = 1.7125
# Point 69/80 r = 1.7375
# Point 70/80 r = 1.7625
# Point 71/80 r = 1.7875
# Point 72/80 r = 1.8125
# Point 73/80 r = 1.8375
# Point 74/80 r = 1.8625
# Point 75/80 r = 1.8875
# Point 76/80 r = 1.9125
# Point 77/80 r = 1.9375
# Point 78/80 r = 1.9625
# Point 79/80 r = 1.9875
# Done in 0.01 min (cpu), 0.01 min (real)

# %%
# !combine -M MultiDimFit higgsCombine.datacard_by_hand.snapshot.expected.MultiDimFit.mH120.root -n .datacard_by_hand_expected.freezeAll --rMin 0 --rMax 2 --algo grid --points 800 --snapshotName MultiDimFit --freezeParameters allConstrainedNuisances -t -1 --expectSignal 1
# Out:
#  <<< Combine >>>
#  <<< v10.0.0 >>>
# >>> Random number generator seed is 123456
# >>> Method used is MultiDimFit
# Doing initial fit:
#  POI: r= 1 -> [0,2]
# Point 0/800 r = 0.00125
# Point 1/800 r = 0.00375
# Point 2/800 r = 0.00625
# Point 3/800 r = 0.00875
# Point 4/800 r = 0.01125
# Point 5/800 r = 0.01375
# Point 6/800 r = 0.01625
# Point 7/800 r = 0.01875
# Point 8/800 r = 0.02125
# Point 9/800 r = 0.02375
# Point 10/800 r = 0.02625
# Point 11/800 r = 0.02875
# Point 12/800 r = 0.03125
# Point 13/800 r = 0.03375
# Point 14/800 r = 0.03625
# Point 15/800 r = 0.03875
# Point 16/800 r = 0.04125
# Point 17/800 r = 0.04375
# Point 18/800 r = 0.04625
# Point 19/800 r = 0.04875
# Point 20/800 r = 0.05125
# Point 21/800 r = 0.05375
# Point 22/800 r = 0.05625
# Point 23/800 r = 0.05875
# Point 24/800 r = 0.06125
# Point 25/800 r = 0.06375
# Point 26/800 r = 0.06625
# Point 27/800 r = 0.06875
# Point 28/800 r = 0.07125
# Point 29/800 r = 0.07375
# Point 30/800 r = 0.07625
# Point 31/800 r = 0.07875
# Point 32/800 r = 0.08125
# Point 33/800 r = 0.08375
# Point 34/800 r = 0.08625
# Point 35/800 r = 0.08875
# Point 36/800 r = 0.09125
# Point 37/800 r = 0.09375
# Point 38/800 r = 0.09625
# Point 39/800 r = 0.09875
# Point 40/800 r = 0.10125
# Point 41/800 r = 0.10375
# Point 42/800 r = 0.10625
# Point 43/800 r = 0.10875
# Point 44/800 r = 0.11125
# Point 45/800 r = 0.11375
# Point 46/800 r = 0.11625
# Point 47/800 r = 0.11875
# Point 48/800 r = 0.12125
# Point 49/800 r = 0.12375
# Point 50/800 r = 0.12625
# Point 51/800 r = 0.12875
# Point 52/800 r = 0.13125
# Point 53/800 r = 0.13375
# Point 54/800 r = 0.13625
# Point 55/800 r = 0.13875
# Point 56/800 r = 0.14125
# Point 57/800 r = 0.14375
# Point 58/800 r = 0.14625
# Point 59/800 r = 0.14875
# Point 60/800 r = 0.15125
# Point 61/800 r = 0.15375
# Point 62/800 r = 0.15625
# Point 63/800 r = 0.15875
# Point 64/800 r = 0.16125
# Point 737/800 r = 1.84375
# Point 738/800 r = 1.84625
# Point 739/800 r = 1.84875
# Point 740/800 r = 1.85125
# Point 741/800 r = 1.85375
# Point 742/800 r = 1.85625
# Point 743/800 r = 1.85875
# Point 744/800 r = 1.86125
# Point 745/800 r = 1.86375
# Point 746/800 r = 1.86625
# Point 747/800 r = 1.86875
# Point 748/800 r = 1.87125
# Point 749/800 r = 1.87375
# Point 750/800 r = 1.87625
# Point 751/800 r = 1.87875
# Point 752/800 r = 1.88125
# Point 753/800 r = 1.88375
# Point 754/800 r = 1.88625
# Point 755/800 r = 1.88875
# Point 756/800 r = 1.89125
# Point 757/800 r = 1.89375
# Point 758/800 r = 1.89625
# Point 759/800 r = 1.89875
# Point 760/800 r = 1.90125
# Point 761/800 r = 1.90375
# Point 762/800 r = 1.90625
# Point 763/800 r = 1.90875
# Point 764/800 r = 1.91125
# Point 765/800 r = 1.91375
# Point 766/800 r = 1.91625
# Point 767/800 r = 1.91875
# Point 768/800 r = 1.92125
# Point 769/800 r = 1.92375
# Point 770/800 r = 1.92625
# Point 771/800 r = 1.92875
# Point 772/800 r = 1.93125
# Point 773/800 r = 1.93375
# Point 774/800 r = 1.93625
# Point 775/800 r = 1.93875
# Point 776/800 r = 1.94125
# Point 777/800 r = 1.94375
# Point 778/800 r = 1.94625
# Point 779/800 r = 1.94875
# Point 780/800 r = 1.95125
# Point 781/800 r = 1.95375
# Point 782/800 r = 1.95625
# Point 783/800 r = 1.95875
# Point 784/800 r = 1.96125
# Point 785/800 r = 1.96375
# Point 786/800 r = 1.96625
# Point 787/800 r = 1.96875
# Point 788/800 r = 1.97125
# Point 789/800 r = 1.97375
# Point 790/800 r = 1.97625
# Point 791/800 r = 1.97875
# Point 792/800 r = 1.98125
# Point 793/800 r = 1.98375
# Point 794/800 r = 1.98625
# Point 795/800 r = 1.98875
# Point 796/800 r = 1.99125
# Point 797/800 r = 1.99375
# Point 798/800 r = 1.99625
# Point 799/800 r = 1.99875
# Done in 0.00 min (cpu), 0.00 min (real)

# %%
# !python3 combine_scripts/plot1DScan.py higgsCombine.datacard_by_hand_expected.MultiDimFit.mH120.root --others 'higgsCombine.datacard_by_hand_expected.freezeAll.MultiDimFit.mH120.root:FreezeAll:2' -o combine_plots/likelihood_scan_expected --breakdown Syst,Stat
# Out:
# --------------------------------------
# combine_plots/likelihood_scan_expected
# --------------------------------------
# [{'lo': 0.9069304518912892, 'hi': 1.1117213602602136, 'valid_lo': True, 'valid_hi': True}]
# [{'lo': 0.822470661398969, 'hi': 1.221998961319498, 'valid_lo': True, 'valid_hi': True}]
# [{'lo': 0.9958812015326982, 'hi': 1.0041286517352621, 'valid_lo': True, 'valid_hi': True}]
# [{'lo': 0.9917723051174523, 'hi': 1.0082672323201574, 'valid_lo': True, 'valid_hi': True}]
# Info in <TCanvas::Print>: pdf file ./combine_plots/likelihood_scan_expected.pdf has been created
# Info in <TCanvas::Print>: png file ./combine_plots/likelihood_scan_expected.png has been created

# %%
display(IFrame("combine_plots/likelihood_scan_expected.png", width=800, height=600))
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="combine_plots/likelihood_scan_expected.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
